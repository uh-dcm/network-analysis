# %% [markdown]
# ## Installation and setup
#
# First you need install tge [library](https://github.com/mnets/pymnet) we are using.

# %%
# !pip install pymnet
# Out:
# Requirement already satisfied: pymnet in ./.venv/lib/python3.14/site-packages (1.0.0)
# Requirement already satisfied: matplotlib>=3.7.0 in ./.venv/lib/python3.14/site-packages (from pymnet) (3.10.8)
# Requirement already satisfied: numpy>=1.23.0 in ./.venv/lib/python3.14/site-packages (from pymnet) (2.4.0)
# Requirement already satisfied: scipy>=1.10.0 in ./.venv/lib/python3.14/site-packages (from pymnet) (1.16.3)
# Requirement already satisfied: networkx<4.0,>=2.0 in ./.venv/lib/python3.14/site-packages (from pymnet) (3.6.1)
# Requirement already satisfied: bliss-bind>=0.3.0 in ./.venv/lib/python3.14/site-packages (from pymnet) (0.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->pymnet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->pymnet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->pymnet) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->pymnet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->pymnet) (25.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->pymnet) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->pymnet) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->pymnet) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->pymnet) (1.17.0)

# %%
from pymnet import *
import csv

# %% [markdown]
# ## Creating the network
#
# 1. Create a new network object
# 1. Add layers
# 1. Add all nodes
# 1. Add connections per layer

# %%
network = MultiplexNetwork(couplings='categorical')

# %%
layers = ['layer1', 'layer2']

for layer in layers:
    network.add_layer( layer )

# %%
nodes = ['node1', 'node2', 'node3', 'node4']

for n in nodes:
    network.add_node( n )

# %%
import itertools
import math
import random

for layer in layers:
    
    for pair1, pair2 in itertools.permutations( nodes, 2 ): ## populate the dataset, here through each layer and then each pair
        network[ pair1, layer ][ pair2, layer ] = random.randrange(0, 5)

# %% [markdown]
# ## Drawing etc.
#
# See [documentation](https://mnets.github.io/pymnet/reference.html) for all opportunities.

# %%
fig = draw(network,
    layout="spring",
    #layerLabelRule={},
    #nodeLabelRule={},
    defaultNodeLabelSize = 0.1,
    defaultEdgeWidth = 0.25,
    defaultEdgeAlpha= 0.3,
    nodeSizeRule={"rule":"degree","propscale":0.05},
    edgeColorRule={"rule":"edgeweight","colormap":"jet","scaleby":0.1}
)
