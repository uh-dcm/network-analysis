# %% [markdown]
# # Exponential Graph Models (ERGM)
#
# There really doesn't seem to be a good Python implementation of ERGM.
# The one I could find still somewhat maintained is [pyERGM](https://tomtalp.github.io/pyERGM/), but I needed to read quite a bit of source code (not documentation) to understand what is happening and there seem to be irregularities with documentation and source code.
